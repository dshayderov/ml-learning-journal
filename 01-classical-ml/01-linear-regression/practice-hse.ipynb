# %% [markdown]
# # Практика: <название темы>
#
# **Источник задания:** <HSE семинар N / mlcourse.ai тема N / Kaggle Inclass ...>
#
# **Связанный конспект:** [notes.md](notes.md)
#
# Этот ноутбук рабочий — здесь нормально, если местами грязно и много экспериментов. Финальные выводы и чистое объяснение — в notes.md.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## Задание
#
# <условие задачи своими словами>

# %%
# решение

# %% [markdown]
# ## Вывод
#
# <что получилось, что понял(а), какой результат/метрика>
